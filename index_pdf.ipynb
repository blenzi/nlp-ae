# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: elasticsearch==7.17.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (7.17.2)
# Requirement already satisfied: elasticsearch-dsl<8.0.0,>=7.0.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (7.4.0)
# Requirement already satisfied: PyMuPDF==1.19.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.19.1)
# Requirement already satisfied: streamlit==1.8.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.8.1)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from elasticsearch==7.17.2->-r requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: certifi in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from elasticsearch==7.17.2->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: pillow>=6.2.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (9.0.1)
# Requirement already satisfied: pympler>=0.9 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (4.11.3)
# Requirement already satisfied: pandas>=0.21.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: tornado>=5.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (6.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: pyarrow in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: cachetools>=4.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: validators in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (0.19.0)
# Requirement already satisfied: gitpython!=3.1.19 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (3.1.27)
# Requirement already satisfied: toml in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: attrs in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (21.4.0)
# Requirement already satisfied: requests in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (2.27.1)
# Requirement already satisfied: numpy in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (1.22.3)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (3.20.1)
# Requirement already satisfied: click<8.1,>=7.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (8.0.4)
# Requirement already satisfied: packaging in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: watchdog in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (2.1.7)
# Requirement already satisfied: blinker in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (1.4)
# Requirement already satisfied: python-dateutil in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: altair>=3.2.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (4.2.0)
# Requirement already satisfied: tzlocal in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (4.2)
# Requirement already satisfied: semver in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from streamlit==1.8.1->-r requirements.txt (line 4)) (2.13.0)
# Requirement already satisfied: six in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from elasticsearch-dsl<8.0.0,>=7.0.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: toolz in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (0.11.2)
# Requirement already satisfied: entrypoints in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: jinja2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit==1.8.1->-r requirements.txt (line 4)) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.8.1->-r requirements.txt (line 4)) (3.0.5)
# Requirement already satisfied: zipp>=0.5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit==1.8.1->-r requirements.txt (line 4)) (3.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: pytz>=2020.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pandas>=0.21.0->streamlit==1.8.1->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (7.7.0)
# Requirement already satisfied: ipykernel>=5.1.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (6.13.0)
# Requirement already satisfied: traitlets>=4.3.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: nest-asyncio in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.5.5)
# Requirement already satisfied: ipython>=7.23.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (8.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (7.3.0)
# Requirement already satisfied: psutil in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (5.9.0)
# Requirement already satisfied: jedi>=0.16 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.18.1)
# Requirement already satisfied: stack-data in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: decorator in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: pickleshare in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (3.0.29)
# Requirement already satisfied: setuptools>=18.5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (61.2.0)
# Requirement already satisfied: backcall in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (2.12.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (5.4.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from jinja2->altair>=3.2.0->streamlit==1.8.1->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (4.9.2)
# Requirement already satisfied: pyzmq>=22.3 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (22.3.0)
# Requirement already satisfied: fastjsonschema in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (2.15.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (6.4.11)
# Requirement already satisfied: terminado>=0.8.3 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.13.3)
# Requirement already satisfied: prometheus-client in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (6.5.0)
# Requirement already satisfied: argon2-cffi in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (21.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: bleach in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: tinycss2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: defusedxml in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: pycparser in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from packaging->streamlit==1.8.1->-r requirements.txt (line 4)) (2.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from requests->streamlit==1.8.1->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from requests->streamlit==1.8.1->-r requirements.txt (line 4)) (2.0.12)
# Requirement already satisfied: executing in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: pure-eval in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: asttokens in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==1.8.1->-r requirements.txt (line 4)) (2.0.5)
# Requirement already satisfied: pytz-deprecation-shim in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from tzlocal->streamlit==1.8.1->-r requirements.txt (line 4)) (0.1.0.post0)
# Requirement already satisfied: tzdata in /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal->streamlit==1.8.1->-r requirements.txt (line 4)) (2022.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pprint
from datetime import datetime
from pathlib import Path
import requests
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Index, analyzer
from elasticsearch_dsl.query import MultiMatch

# %% [markdown]
# ### Download PDF

# %%
pdf = "Etude d'impact Projet PV GUELTAS.pdf"

if not Path(pdf).exists():
    # https://www.projets-environnement.gouv.fr/page/fiche/?q=recordsid:2019396615
    url = 'https://osmose.numerique.gouv.fr/front/publicLink/publicDownload.jsp?id=e1b3de34-46d2-4f71-b84e-cb3a081a55a8c2fe4367-d254-42df-8bfa-543f87ee4a91'
    with open("Etude d'impact Projet PV GUELTAS.pdf", 'wb') as f:
        f.write(requests.get(url).content)

# %%
import fitz
import itertools


def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

def get_text_blocks(doc, title, next_title):
    """
    Return an iterator with a tuple (x0, y0, x1, y1, text) for each the text block

    Args:
        pdf (str or fitz.Document): PDF document
        text_blocks (bool, default=True): add text blocks
    """
    for page_no in range(title['page'], next_title.get('page', doc.page_count - 1) + 1):
        page = doc.load_page(page_no)
        for x0, y0, x1, y1, text, block_no, block_type in sorted(page.get_text('blocks'), key=lambda x: x[1]):
            if block_type != 0 or (page_no == title['page'] and y1 < title['to'].y):
                continue
            if next_title and page_no == next_title['page'] and y1 >= next_title['to'].y:
                return
            yield x0, y0, x1, y1, text
    
def get_toc(pdf, add_text_blocks=True):
    """
    Return the a list with the table of contents of the PDF document. 
    Each entry is a dictionary containing: 
        level (int), title (str), page (str), to (Point), all_titles (list with title hierarchy), [text_blocks (list)]

    Args:
        pdf (str or fitz.Document): PDF document
        add_text_blocks (bool, default=True): add text blocks
    """
    doc = pdf if isinstance(pdf, fitz.Document) else fitz.open(pdf)
    toc = [{'level': item[0], 'title': item[1], **item[3]} for item in doc.get_toc(simple=False)]

    all_titles = []
    for ititle, (title, next_title) in enumerate(pairwise(toc + [{}])): # add empty title for last one
        if add_text_blocks:
            text_blocks = list(get_text_blocks(doc, title, next_title))
            toc[ititle]['text_blocks'] = text_blocks
        all_titles = [j for i, j in enumerate(all_titles) if i < title['level'] - 1] + [title['title']]
        toc[ititle]['all_titles'] = all_titles
    return toc

toc = get_toc(pdf)

# %%
for item in toc[:10]:
    for level, title in enumerate(item['all_titles']):
        print('\t'*level + '*** ' + title)
    print('\n'.join(i[-1] for i in item['text_blocks']))
    print('_.'*60)
# Out:
# *** 1 RESUME NON TECHNIQUE
# 1
# RESUME NON TECHNIQUE
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 1 RESUME NON TECHNIQUE
# 	*** 1.1 Présentation synthétique du projet
# 1.1 Présentation synthétique du projet
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 1 RESUME NON TECHNIQUE
# 	*** 1.1 Présentation synthétique du projet
# 		*** 1.1.1 Localisation
# 1.1.1 Localisation
#
# La zone d’implantation du projet se situe sur la commune de Gueltas, dans le département du
# Morbihan (56), en région Bretagne.
# Le site d’implantation se situe sur une zone remaniée du site de stockage des déchets à Gueltas.
# Ce dôme, qui a été exploité par Suez Recyclage et Valorisation (Suez RV) de 1995 à 2006 est
# aujourd’hui en suivi d’exploitation. A noter qu’un nouveau site de stockage est en cours
# d’exploitation dans la continuité de ce dôme, à l’Ouest du site.
# Le projet est localisé dans un secteur relativement isolé, à moins de 2km à l’ouest du bourg. La
# situation géographique du site est présentée sur la page suivante.
# Le tableau ci-dessous reprend les informations administratives concernant le site :
#
#
# Tableau 1 : Informations administratives
#
#
#
# Région
# Bretagne
#
# Département
# 56 Morbihan
#
# Commune
# Gueltas 56920
#
# Lieu dit / adresse
# Ecopôle de Gueltas, Route départementale 125
#
# Surface de l’ISDND
# 117,15 ha
#
# Surface du projet
# 17,5 ha
#
# Propriétaire
# SUEZ RV Ouest
#
# Section et parcelles
# concernées
# B128 et B118
#
#
#
#
# 1 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
#
#
# Figure 1 : Localisation géographique du projet
#
# L’accès au site s’effectue depuis la RD125 qui relie Cléguérec à Rohan. L’entrée de la centrale
# photovoltaïque sera commune avec l’entrée du site de l’Ecopôle de Gueltas exploité par Suez
# Recyclage et Valorisation.
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 1 RESUME NON TECHNIQUE
# 	*** 1.1 Présentation synthétique du projet
# 		*** 1.1.2 Présentation technique du projet
# 1.1.2 Présentation technique du projet
#
# Le terrain présente des caractéristiques techniques optimales pour l’installation de panneaux
# photovoltaïques (ensoleillement, orientation, topographie, accessibilité, …).
# Le projet prévoit l’installation d’une centrale solaire photovoltaïque composée de
# 27 780 panneaux sur une zone remaniée de l’ISDND de Gueltas exploitée de 1995 à 2006. Cette
# technologie permet de transformer l’énergie solaire en électricité pouvant être injectée sur le
# réseau électrique comme illustré par le schéma suivant :
#
#
#
#
# Figure 2 : Schéma du principe de la technologie photovoltaïque
#
# 2 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
# Les chiffres principaux du projet sont synthétisés dans le tableau ci-dessous (chiffres
# approximatifs) :
#
#
#
# Synthèse du projet
#
# 
# Type de terrain : zone remaniée d’ISDND
#
# 
# Emprise foncière : 17,5 ha
#
# Terrain
#
# 
# Emprise des panneaux solaires au sol : 5,9 ha
#
# 
# Surface totale des panneaux solaires : 6,0ha
#
# Installation
# 
# Centrale photovoltaïque de 12 MWc
#
# 
# 27 780 modules de type Silicium monocristallin
#
# 
# Implantation des panneaux sur des structures fixes
# (environ 926 structures)
#
# 
# Puissance unitaire du module : 435 Wc
#
# Spécificités techniques
#
# 
# Dimensions des modules : 2,067 x 1,046 x 0,046 m
#
# 
# 4 postes de transformation de 39 m² chacun
#
# 
# 1 poste de livraison de 36 m²
#
# 
# 1 conteneur de stockage de 30 m²
#
# 
# Une production d’énergie annuelle estimée à 13 228 MWh/an
#
# Production et Équivalent
# en termes de foyers
#
# 
# Équivalent en termes de foyers : 4 000 foyers
#
# 
#  5 575,30    tonnes de CO2 évitées par an par rapport à un
# système à gaz.
#
#  (Hypothèse de CO2 produit par kWh produit : 476 gCO2/kWh)
#
# 
#  3 778,99   tonnes de CO2 évitées par an par rapport à la moyenne
# de CO2 produit par MWh en Europe
#
# Quantité de CO2 évitée
#
# (Hypothèse de CO2 produit par kWh produit : 340 gCO2/kWh)
#
# 
# 395,11   tonnes de CO2 évitées par an par rapport à la moyenne
# de CO2 produit par MWh en France
#
# (Hypothèse de CO2 produit par kWh produit : 84,2 gCO2/kWh)
#
# Source : Ademe
#
#
# Le plan de masse des installations projetées est présenté sur la figure suivante :
#
# 3 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
#
#
# Figure 3 : Extrait du plan d'implantation du projet – source : ENGIE Green
#
#
# À noter : la présence des réseaux biogaz (en rouge) et lixiviat (en marron) sur le dôme de l’ISDND
# de Gueltas a été prise en compte pour la définition de l’implantation des panneaux
# photovoltaïques. Ainsi des distances de sécurité et d’accès seront maintenues autour de ces
# équipements.
#
# 4 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone remaniée de l’ISDND de Guletas
#
#
#
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 1 RESUME NON TECHNIQUE
# 	*** 1.2 Synthèse de l’état initial
# 1.2 Synthèse de l’état initial
#
#
#
# Thématique
# Description
# Enjeux
#
# Climat
# Climat océanique dégradé.
# Ensoleillement moyen de 143,8 h/mois.
# Aucun
#
# Topographie
# Le site du projet qui correspond à une zone remaniée d’une ISDND forme un dôme dont la cote topographique varie entre 150 et 170 m NGF.
# L’altitude des terrains aux abords du site varie autour de 140 m NGF.
# Faible
#
# Sol
# Le site d’implantation du projet correspond à une zone remaniée d’une ISDND. Les panneaux seront implantés sur la couverture des dômes composés
# de 30 cm minimum de terre végétale, d’une géomembrane puis de 1m minimum d’argile
# Faible
#
# Première masse d’eau rencontrée : « La Vilaine » (FRFG015).
# Objectifs de bon état quantitatif en 2015 et bon état chimique en 2021 ou 2027.
# Aucun captage d’eau potable sur la commune.
# Le site n’est concerné par aucun périmètre de protection
#
# Masses d’eaux
#
# Faible
#
# souterraines
#
# Réseau hydrographique peu développé dans le secteur.
# Le site est implanté sur le bassin versant du ruisseau de Gueltas.
# Le ruisseau Gueltas constitue le milieu récepteur des rejets des eaux pluviales des bassins EP situé à l’Est de l’ISDND
# Aucune donnée sur la qualité des eaux et sur les objectifs de qualité.
#
# Masses d’eaux
# superficielles
#
# Faible
#
# Ruissellement des eaux
#
# pluviales
# Gestion des eaux pluviales existante sur le site de l’ISDND.
# Faible
#
# ZNIEFF la plus proche à 1 km du site.
# Site non concerné par la trame verte et bleue.
# Site d’étude hors zone humide.
#
# Milieu naturel : Zonages
#
# Faible
#
# réglementaires et
#
# protection
#
# Végétation herbacée dense à l’Est du site
# Végétation ouverte à l’Ouest
# Fourrés de végétation ligneuses
# Aucun habitat patrimonial sur le site
#
# Faible
#
# Milieu naturel : Habitat
#
# Milieu naturel : Flore
# Aucune espèce végétale protégée ou patrimoniale sur le site
# Faible
#
# Fort au niveau des bosquets
#
# Milieu naturel : Avifaune
# Quatre espèces patrimoniales observée et nidification probable ou certaine sur le site.
# Les micro-parcelles de bosquets constituent les zones préférentielles de ces espèces.
#
# Faible sur le reste du site
#
# Chiroptères
# Les investigations ont permis de recenser 7 espèces de chiroptères.
# Faible (pour 5 espèces) à
# moyen (pour 2 espèces)
#
# Milieu naturel :
#
# Aucune espèce patrimoniale de mammifères n’a été observée
# Aucune espèce patrimoniale d’insectes n’a été observée
# Aucune espèce de reptiles n’a été observée
# La Grenouille verte, espèce protégée et patrimoniale, a été observée en périphérie de la zone d’implantation du projet (présence limitée au niveau des
# bassins). Aucun milieu n’est favorable à cette espèce ni à d’autre espèces d’amphibien sur la zone d’implantation du projet
#
# Milieu naturel : Autre
#
# Faible
#
# faune
#
# Occupation du sol
# Site correspondant à une zone remaniée de l’ISDND de Gueltas
# Faible
#
# 5 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone remaniée de l’ISDND de Guletas
#
#
#
#
# Thématique
# Description
# Enjeux
#
# Accès possible par la route départementale RD125 puis par la voie d’accès de l’Ecopôle de Gueltas. Accès au Poste de Livraison situé en limite de
# propriété possible via un aménagement depuis la voie communale longeant le site au Sud.
# Faible
#
# Accès au site
#
# Habitat
# Le projet s’inscrit dans un habitat rural dispersé, marqué par la présence de petits villages ou hameaux.
# Les hameaux les plus proches sont situés entre 750 m et 1,5 km du site.
# Faible
#
# Qualité de l’air
# La qualité de l’air dans le secteur d’étude ne fait l’objet d’aucune mesure.
# Bonne qualité de l’air sur la station de suivi de Saint-Brieuc à 50 km du site.
# Faible
#
# Bruit
# Projet dans un environnement à dominante rurale marqué par l’exploitation de l’Ecopôle de Gueltas et la nouvelle ISDND. Ambiance sonore du site
# considérée comme peu bruyante.
# Faible
#
# Le projet n’est concerné par aucune servitude de protection des monuments historiques (MH le plus proche à 4 km)
# Aucun site classé ou inscrit n’a été recensé sur les communes de Gueltas, ni sur les communes limitrophes.
# Le site n’est pas concerné par une zone de présomption de prescription archéologique
#
# Faible
#
# Patrimoine culturel
#
# Pas d’enjeu au niveau de l’aire d’étude éloignée. Sur l’aire d’étude rapprochée, le réseau de haies, bosquets et bandes boisées cadrent les visibilités.
# Seules les parcelles séparant l’ISDND de la RD125 ont une perception sur le site du projet. Sur le site d’étude, les plantations de Saules partout en périphérie
# du site et de l’ISDND masquent la visibilité depuis l’extérieur.
#
# Faible
#
# Paysage
#
# Le site du projet n’est pas directement concerné par des risques naturels.
# Du fait de l’implantation du projet sur une zone remaniée d’ISDND, le réseau de gestion du biogaz est présent sur ce dôme.
# Moyen
#
# Risques naturels et
#
# technologiques
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 1 RESUME NON TECHNIQUE
# 	*** 1.3 Synthèse des impacts et des mesures associées
# 1.3 Synthèse des impacts et des mesures associées
#
# Thématique
# Phase du
#
# projet
# Impact potentiels
# Niveau
# d’impact
# Mesures d’évitement et de réduction
# Impact
# résiduel
#
# Mise en place de mesures simples pour réduire l’émission de gaz
# de combustion :
#
# Phase travaux
# Augmentation des émissions de gaz à effet de serre et de poussière liée aux
# engins.
# Faible
#
# -
# Respect de la limitation de vitesse (30 km/h),
#
# Faible
#
# -
# Arrêt des moteurs lorsque les engins sont à l’arrêt,
#
# -
# Suivi et entretien périodique des engins.
#
# Climat / Air
#
# L’exploitation de panneaux photovoltaïques ne produit ni émission gazeuse ni
# poussière ni émission polluante.
# Le projet permettra globalement l’évitement d’émissions de gaz à effet de serre
# qui auraient été nécessaires à la production de la même quantité d’électricité
# dans des centrales électriques conventionnelles. Economie de 13 829 tonnes
# de CO2 sur 35 ans.
#
# Phase
#
# Positif
# -
# Positif
#
# exploitation
#
# Phase travaux
# Le projet s’adaptera aux contraintes du terrain liées au dôme de l’ISDND de
# Gueltas.
# Nul
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique.
# Nul
#
# Topographie
#
# Phase
#
# L’installation des panneaux photovoltaïques n’affectera pas la topographie du
# site.
# Nul
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique.
# Nul
#
# exploitation
#
# Mesures dans le cahier des charges des entreprises :
# - réalisation d’une aire de travaux pour l’entreposage du matériel,
# - lavage et ravitaillement des engins en carburant à l’extérieur du
# site,
# - contenants de produits installés sur rétention
#
# Mise à nue du sol durant les terrassements pendant les travaux.
#
# Sol et Sous-
#
# Toutefois aucun impact sur le sol et le sous-sol en raison de la présence d’une
# couverture sur les dômes de l’ISDND (30 cm terre végétale, géomembrane, 1
# m minimum d’argile).
#
# sol
# Phase travaux
#
# Faible
#
# Faible
#
# 6 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone remaniée de l’ISDND de Guletas
#
#
#
#
# Thématique
# Phase du
#
# projet
# Impact potentiels
# Niveau
# d’impact
# Mesures d’évitement et de réduction
# Impact
# résiduel
#
# Note pour les entreprises récapitulant les exigences
# environnementales (gestion des produits dangereux, gestion des
# déchets…).
# Information et sensibilisation du personnel.
#
# Sol et Sous-
#
# sol
# Phase travaux
#
#
#
#
#
# Choix d’utiliser des longrines béton pour la fixation des panneaux
# afin de protéger la couverture et le massif des déchets.
# Les structures porteuses pourront être reliées entre elles pour une
# répartition homogène du poids des structures sur l’ensemble du
# dôme.
#
# Le projet va générer une imperméabilisation des sols due aux structures bâties,
# d’environ 7 630 m² (4,4% de l’emprise de la centrale photovoltaïque).
#
# Phase
#
# Sol et Sous-
#
# Moyen
#
# Faible
#
# exploitation
#
# sol
#
# La mise en place des panneaux peut avoir un effet de tassement sur les sols et
# le massif de déchets.
#
# La phase chantier ne nécessite aucun prélèvement d’eau.
# Nul
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique
# Nul
#
# L’incidence sur la nappe superficielle sera nulle car les travaux de
# terrassement n’interviendront que sur les premiers centimètres de la couverture
# du dôme.
#
# Nul
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique.
# Nul
#
# Phase travaux
#
# Faible
# Les éventuels produits utilisés seront stockés sur des aires
# imperméabilisées ou sur rétention.
# Aucun produit chimique (pesticides, herbicides) ne sera employé.
#
# En cas de situation accidentelle, les travaux pourraient générer des rejets
# liquides. Toutefois la présence de la couverture et des barrières de sécurité de
# l’ISDND réduit fortement le risque de pollutions des eaux souterraines.
#
# Nul
#
# La phase d’exploitation ne nécessite aucun prélèvement d’eau.
# Nul
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique.
# Nul
#
# Masses d’eau
#
# souterraine
#
# Les éventuelles eaux de lavage des panneaux (une fois par an maximum) ne
# comprendront que des matières en suspension présentes dans l’atmosphère.
# Faible
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique.
# Faible
#
# Phase
#
# exploitation
#
# Les transformateurs seront installés à l’intérieur de locaux
# techniques équipés de bacs de rétention ;
#
# En cas de situation accidentelle, les transformateurs pourraient générer des
# rejets liquides.
# Faible
#
# Les éventuels produits utilisés seront stockés sur des aires
# imperméabilisées ou sur rétention.
#
# Nul
#
# Aucun produit chimique (pesticides, herbicides) ne sera employé.
#
# Faible
# impact
# qualitatif
#
# Le déplacement des terres au moyen d’engins peut entraîner la mise en
# suspension de particules dans les fossés de collecte des eaux pluviales. Cet
# impact sera limité par le volume volontairement faible de remblais mobilisés.
#
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique
# Faible
#
# Phase travaux
#
# Masses d’eau
# superficielle
#
# Le projet va générer une imperméabilisation des sols due aux structures bâties,
# d’environ 7 630 m² soit 4,4% de l’emprise de la centrale photovoltaïque.
# 34% de la pluviométrie seront interceptés par les panneaux.
# La mise en œuvre du projet ne modifiera pas la gestion actuellement des eaux
# de ruissellement du site.
#
# Les caractéristiques techniques des panneaux (hauteur,
# inclinaison, espaces entre les modules) et la distance entre les
# rangées de panneaux permettront de maintenir de bonnes
# conditions de ruissellement des eaux
#
# Faible
# impact
#
# Phase
#
# Faible
#
# exploitation
#
# quantitatif
#
# En cas de situation accidentelle, les transformateurs pourraient générer des
# rejets liquides.
#
# Les transformateurs seront installés à l’intérieur de locaux
# techniques équipés de bacs de rétention
# Les éventuels produits utilisés seront stockés sur des aires
# imperméabilisées ou sur rétention
# Aucun produit chimique (pesticides, herbicides) ne sera employé
#
# Faible
# impact
# qualitatif
#
# Phase
#
# Masses d’eau
# superficielle
#
# Faible
#
# Les éventuelles eaux de lavage des panneaux (une fois par an) ne
# comprendront que des matières en suspension présentes dans l’atmosphère et
# donc sans risque pour le milieu naturel
#
# exploitation
#
# 7 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone remaniée de l’ISDND de Guletas
#
#
#
#
# Thématique
# Phase du
#
# projet
# Impact potentiels
# Niveau
# d’impact
# Mesures d’évitement et de réduction
# Impact
# résiduel
#
# Milieu naturel
# Phase travaux
# Dégradation de la végétation (pas d’espèces patrimoniales ou protégée)
# Faible
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique
# Faible
#
#  L’exploitant du site ICPE est tenu de faire un débroussaillage
# régulier du site. C’est donc lui qui est en charge les impacts
# potentiels sur l’avifaune. Il respecte les recommandations qui lui
# ont été faites lors de la création de l’ICPE. Par conséquent, les
# travaux seront réalisés après débroussaillage, ils auront donc un
# faible impact sur l’avifaune.
#
# Destruction de nids et d’habitats de reproduction pour l’avifaune
# Fort
#
# Faible
#
# Phase travaux
#
# Les travaux seront réalisés après débroussaillage du site par
# l’exploitant de l’ICPE. Ils auront donc un faible impact sur les
# reptiles.
# Exclusion de toute utilisation de produit phytosanitaire dans
# l’entretien du site
#
# Destruction de reptiles et d’habitat favorables aux reptiles
# Moyen
#
# Faible
#
# Milieu naturel
#
# Les travaux seront réalisés après débroussaillage du site par
# l’exploitant de l’ICPE. Ils auront donc un faible impact sur la
# végétation.
#
# Destruction de végétation au cours des opérations de maintenance
# Faible
#
# Faible
#
# Phase
#
# exploitation
#
# Non éclairage de la zone d’implantation de la centrale
# photovoltaïque
# Clôtures avec « passes à faune »
#
# Dérangement des espèces nocturnes, diminution des déplacements (continuité
# écologique)
# Faible
#
# Faible
#
# Phase travaux
# Le sol passera d’un état végétalisé à un sol nu. La végétation pourra se
# réinstaller sous les panneaux après les travaux
# Faible
# Aucune mesure n’est prévue au regard de l’absence d’incidence
# spécifique
# Faible
#
# Occupation
#
# du sol
#
# Phase
#
# Le projet va permettre de valoriser et de restituer une valeur fonctionnelle aux
# terrains réhabilités d’une zone remaniée d’ISDND
# Positif
# -
# Positif
#
# exploitation
#
# Phase travaux
# Le trafic pendant la phase travaux est estimé en moyenne à 10 rotations par
# jour de camions.
# Faible
# Aucune mesure n’est prévue étant donné le faible trafic généré
# Faible
#
# Voirie et
#
# accès
#
# Phase
#
# le trafic sera restreint aux visites des techniciens de maintenance et de
# l’exploitant des parcs photovoltaïques qui n’auront lieu que ponctuellement
# Nul
# Aucune mesure n’est prévue étant donné le faible trafic généré
# par l’exploitation
# Nul
#
# exploitation
#
# ENGIE Green consultera des entreprises locales pour la réalisation de la partie
# génie civil / VRD.
# Les travaux engendreront une augmentation de la fréquentation des
# restaurants et hôtels par les ouvriers
#
# Phase travaux
#
# Positif
# -
# Positif
#
# Economie
#
# Phase
#
# En raison de la présence du parc photovoltaïque, la commune de Gueltas
# bénéficiera de recettes fiscales
# Positif
# -
# Positif
#
# exploitation
#
# Mise en place d’une gestion des déchets
# Mise en place de mesures simples pour réduire l’émission de gaz
# de combustion :
# Respect de la limitation de vitesse (30 km/h)
# Arrêt des moteurs lorsque les engins sont à l’arrêt
# Suivi et entretien périodique des engins
# Travaux seront réalisés uniquement en période diurne
#
# Les travaux vont générer des déchets
# La circulation des engins va générer des émissions
# Les travaux vont générer une augmentation du niveau de bruit toutefois les
# habitations les plus proches sont situées à 750 m du site
#
# Phase travaux
#
# Faible
#
# Faible
#
# Cadre de vie
#
# Phase
#
# exploitation
# La production de déchets est négligeable
# Faible
# Les éléments électriques importants (onduleurs, transformateurs)
# seront installés dans des locaux techniques.
# Faible
#
# 8 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone remaniée de l’ISDND de Guletas
#
#
#
#
# Thématique
# Phase du
#
# projet
# Impact potentiels
# Niveau
# d’impact
# Mesures d’évitement et de réduction
# Impact
# résiduel
#
# Le verre qui recouvre les cellules PV est traité anti reflet de
# manière à absorber un maximum de rayons lumineux
#
# L’exploitation de la centrale photovoltaïque ne génère ni émission polluante, ni
# poussières.
# Les onduleurs et les transformateurs peuvent être sources de bruit
# Les modules photovoltaïques réfléchissent une partie de la lumière mais les
# boisements importants autour du site diminuent leur visibilité
#
# Patrimoine
# Phase travaux
# et exploitation
#
# Le site n’est situé dans aucun périmètre de protection de monument historique,
# site classé ou inscrit.
# Nul
# -
# Nul
#
# Les travaux vont nécessiter la fréquentation du site par de nombreux engins de
# construction. Un certain nombre d’installation de chantier vont également
# modifier le paysage en donnant à voir des éléments dont l’image est
# déconnectée du paysage rural actuel.
#
# Phase travaux
#
# Faible
# -
# Faible
#
# Echelle éloignée : aucune visibilité sur le projet car entouré de plantations de
# Saules
# Nul
#
# Nul
#
# Paysage
#
# Absence d’impact notable sur l’environnement (pas de covisibilité,
# pas d’impact sur les axes dynamiques, pas d’impact sur les lieux
# de vie). Le projet ne nécessite pas la mise en place de mesures
#
# Echelle rapprochée : 1 seule vue sur le projet depuis les parcelles agricoles
# séparant l’ISDND de la RD125. Impact visuel notable pour l’espace agricole
# mais négligeable pour la RD et le sentier car présence d’une double haie.
#
# Phase
#
# Faible
# Faible
#
# exploitation
#
# vis-à-vis de l’impact paysager
#
# Echelle du site : implantation sur une zone remaniée en suivi d’exploitation
# occupé par une végétation de friche. Pas d’intérêt paysager majeur.
# Faible
# Faible
#
# Phase travaux
# Risque d’incendie lié à la présence du réseau biogaz.
# Site non soumis aux risques : inondation, séisme, mouvement de terrain
# Faible
# Mesures de sécurité mise en place pendant le chantier (présence
# d’extincteur, interdiction de fumer, etc)
# Faible
#
# Risques
#
# Centrale accessible aux sapeurs-pompiers, réserve incendie sur
# site.
# Respect des distances de sécurité dictées par Suez RV pour
# l’implantation des panneaux vis-à-vis du réseau biogaz.
#
# naturels et
#
# Les équipements électriques sont source de départ de feu. Toutefois les
# installations constituent un coupe-feu vis-à-vis des feux de forêt.
# Risque lié à la présence du réseau biogaz.
#
# Phase
#
# technologique
#
# Faible
#
# Faible
#
# exploitation
#
#
# Au regard de l’évaluation des impacts résiduels du projet, aucune mesure compensatoire ou d’accompagnement n’est nécessaire.
#
#
#
# 9 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 2 PRESENTATION DU DEMANDEUR
# 2
# PRESENTATION DU DEMANDEUR
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 2 PRESENTATION DU DEMANDEUR
# 	*** 2.1 Présentation générale d’ENGIE
# 2.1 Présentation générale d’ENGIE
#
# ENGIE est un acteur mondial de l’énergie et de la transition énergétique, expert dans 3
# métiers : l’électricité, le gaz naturel et les services à l’énergie.
# ENGIE inscrit la croissance responsable au cœur de ses métiers pour relever les grands enjeux
# de la transition énergétique vers une économie sobre en carbone : l’accès à une énergie durable,
# l’atténuation et l’adaptation au changement climatique, la sécurité d’approvisionnement et
# l’utilisation raisonnée des ressources.
# Le groupe déploie avec les particuliers, les villes et les entreprises des solutions énergétiques
# globales fondées sur la production d’une électricité renouvelable ou faiblement émettrice, la
# fourniture de gaz naturel décarboné et l’innovation technologique et numérique.
#
#
#
#
# Figure 4 : Les 3 activités principales d'ENGIE
#
# ENGIE exploite dans le monde 750 centrales qui font appel aux sources d’énergie disponibles
# les moins émettrices telles que l’hydroélectricité, l’éolien terrestre, maritime et flottant, le solaire
# photovoltaïque et thermique, la géothermie terrestre et marine, la biomasse, le biogaz et les
# énergies marines. En 2016, celles-ci ont fourni plus de 500 térawattheures d’électricité et de
# chaleur, soit l’équivalent de la consommation annuelle totale du Canada.
#
# Les chiffres clés d’ENGIE :
#
# 153 090
# Collaborateurs dans le
# monde entier
#
# Des activités dans 70 pays
#
# 16 milliards d’€ d’investissements de
# croissance sur la période 2016-2018 dont
#
# Chiffre d’affaires
#
# 66,6 milliards d’€
#
#  1 milliard dans l’innovation et le digital
#
#
#
#
#
# 10 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 2 PRESENTATION DU DEMANDEUR
# 	*** 2.2 ENGIE Green : un leader des énergies renouvelables en France
# 2.2 ENGIE Green : un leader des énergies renouvelables en
#
# France
#
# ENGIE Green, est une filiale détenue à 100 % par le Groupe ENGIE. Elle est issue de la fusion
# de La Compagnie du Vent au 15 décembre 2017 et de l’intégration des activités de
# développement, d’exploitation et de maintenance de Solairedirect en France.
# ENGIE Green dispose d’une expertise complète dans les domaines du développement, de la
# construction et de l’exploitation et de la maintenance des parcs éoliens et photovoltaïques.
# Implantée dans 16 agences en France ; au cœur des régions, ENGIE Green totalise plus de
# 1300 MW éoliens et 860 MWc solaire installés et exploités ; et alimente en énergie verte
# l’équivalent de 1 700 000 habitants. ENGIE Green est également engagée dans les énergies
# marines renouvelables.
# ENGIE Green est ainsi un leader de la production d’énergie renouvelable en France et est le
# 1er acteur de l’éolien terrestre et du photovoltaïques.
#
#
#
#
# Figure 5 : Implantation des agences ENGIE Green
#
#
#
#
# 11 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.
# *** 2 PRESENTATION DU DEMANDEUR
# 	*** 2.3 Le solaire avec ENGIE Green
# 2.3 Le solaire avec ENGIE Green
#
# Les références actuelles d’ENGIE Green en matière de solaire photovoltaïque s’articulent autour
# de centrale au sol et d’installation en ombrière de parking. Les centrales solaires sont implantées
# en priorité sur des friches industrielles ou sur des surfaces dégradées dans le but de les réhabiliter
# (carrières, ancienne installation de stockage de déchets, sites portuaires, ferroviaires ou
# aérodromes).
#
# Les chiffres clés du solaire avec ENGIE Green :
# 
# 101 centrales photovoltaïques ;
#
# 
# 862 MWc solaires installés et exploités ;
#
# 
# 1 163 GWh produits, soit la consommation électrique annuelle de 485 000 personnes.
#
#
#
#
#
# Figure 6 : Exemples de parc photovoltaïque ENGIE Green
#
#
#
#
# 12 / 196
#
#
# Étude d’impact
# Projet d’implantation d’une centrale photovoltaïque au sol sur une zone
# remaniée de l’ISDND de Guletas
#
#
#
#
# _._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._._.

# %%
# Create a tiny PDF to test the visualisation

with fitz.open("Etude d'impact Projet PV GUELTAS.pdf") as doc1, fitz.open() as doc2:
    doc2.insert_pdf(doc1, from_page=0, to_page = 1)  # first 2 pages
    doc2.save("tmp.pdf")

# %% [markdown]
# ### Elastic search client and configuration

# %%
es = Elasticsearch('http://elasticsearch-master:9200')
print(es)
print(es.info())

index = Index('pdf-index')
index.analyzer(analyzer('default', 'french'))

# delete the index, ignore if it doesn't exist
index.delete(using=es, ignore=404)

# create the index in elasticsearch
index.create(using=es)
# Out:
# <Elasticsearch([{'host': 'elasticsearch-master', 'port': 9200}])>
# {'name': 'elasticsearch-master-1', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'bFpuY_V7RHSbzX5GRz6m6Q', 'version': {'number': '7.13.4', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': 'c5f60e894ca0c61cdbae4f5a686d9f08bcefc942', 'build_date': '2021-07-14T18:33:36.673943207Z', 'build_snapshot': False, 'lucene_version': '8.8.2', 'minimum_wire_compatibility_version': '6.8.0', 'minimum_index_compatibility_version': '6.0.0-beta1'}, 'tagline': 'You Know, for Search'}
# /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages/elasticsearch/connection/base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.13/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'pdf-index'}

# %%
for index, item in enumerate(toc):
    doc = {
        'title': item['title'],
        'all_titles': item['all_titles'],
        'page': item['page'], # all pages for viewing the pdf ?
        'text': '\n'.join(i[-1] for i in item['text_blocks']),
    }
    resp = es.index(index="pdf-index", id=index, document=doc)
    print(resp['result'], end=' ')

print()
# Out:
# created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created created

# %%
m = MultiMatch(query="électricité",
               fields=["title^3", "text"],  # multiplies title score by 3
               fuzziness="AUTO")
s = Search(using=es, index="pdf-index").query(m).highlight("text", fragment_size=200)
response = s.execute()
nhits = response.hits.total.value

print('Total hits:', nhits, '\n')
for hit in response:
    pprint.pprint(hit)

print(response[0].meta.highlight['text'])
# Out:
# Total hits: 15
#
# <Hit(pdf-index/7): {'title': '2.1 Présentation générale d’ENGIE', 'all_titles':...}>
# <Hit(pdf-index/14): {'title': '3.3 Généralités – Principe de base du photovoltaï...}>
# <Hit(pdf-index/16): {'title': '3.4.1 Implantation', 'all_titles': ['3 DESCRIPTIO...}>
# <Hit(pdf-index/60): {'title': '5.1.2.3 Le Schéma Régional Climat Air Énergie (SR...}>
# <Hit(pdf-index/140): {'title': '8.1.1.2 Phase d’exploitation : effets permanents'...}>
# <Hit(pdf-index/47): {'title': '3.9 Réglementation applicable', 'all_titles': ['3...}>
# <Hit(pdf-index/56): {'title': '5.1.1 Contexte énergétique et réglementaire à l’é...}>
# <Hit(pdf-index/66): {'title': '6 DESCRIPTIONS DES ASPECTS PERTINENTS DE L’ETAT A...}>
# <Hit(pdf-index/59): {'title': '5.1.2.2 La programmation pluriannuelle de l’énerg...}>
# <Hit(pdf-index/13): {'title': '3.2 Nature et objet de l’opération', 'all_titles'...}>
# ['2.1 Présentation générale d’ENGIE \n\nENGIE est un acteur mondial de l’énergie et de la transition énergétique, expert dans 3 \nmétiers : <em>l’électricité</em>, le gaz naturel et les services à l’énergie.', 'Le groupe déploie avec les particuliers, les villes et les entreprises des solutions énergétiques \nglobales fondées sur la production d’une <em>électricité</em> renouvelable ou faiblement émettrice, la \nfourniture', 'En 2016, celles-ci ont fourni plus de 500 térawattheures <em>d’électricité</em> et de \nchaleur, soit l’équivalent de la consommation annuelle totale du Canada.']
# /home/coder/local/bin/conda/envs/basesspcloud/lib/python3.10/site-packages/elasticsearch/connection/base.py:200: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.13/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)

# %% [markdown]
# ### Test analyzer

# %%
from elasticsearch.client import IndicesClient
ic = IndicesClient(es)

ic.analyze(
    body={
        "analyzer": "french",
        # "tokenizer": "standard",
        # "filter":  [ "lowercase", "asciifolding" ],
        "text":     "L''électricité produite par mes panneaux solaires, jusqu'à ce que le soleil tombe'"
    }
)
# Out:
# {'tokens': [{'token': 'electricit',
#    'start_offset': 3,
#    'end_offset': 14,
#    'type': '<ALPHANUM>',
#    'position': 1},
#   {'token': 'produit',
#    'start_offset': 15,
#    'end_offset': 23,
#    'type': '<ALPHANUM>',
#    'position': 2},
#   {'token': 'paneau',
#    'start_offset': 32,
#    'end_offset': 40,
#    'type': '<ALPHANUM>',
#    'position': 5},
#   {'token': 'solair',
#    'start_offset': 41,
#    'end_offset': 49,
#    'type': '<ALPHANUM>',
#    'position': 6},
#   {'token': 'soleil',
#    'start_offset': 69,
#    'end_offset': 75,
#    'type': '<ALPHANUM>',
#    'position': 11},
#   {'token': 'tomb',
#    'start_offset': 76,
#    'end_offset': 81,
#    'type': '<ALPHANUM>',
#    'position': 12}]}
